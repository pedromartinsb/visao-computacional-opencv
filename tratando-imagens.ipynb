# %%
import cv2
import matplotlib.pyplot as plt

# %%
imagem = cv2.imread("imagens/px-menina.png")

# %%
plt.imshow(imagem)

# %%
imagem_rgb = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imagem_rgb)

# %%
imagem_rgb.shape
# Out:
# (660, 995, 3)

# %%
imagem_gray = cv2.cvtColor(imagem_rgb, cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(imagem_gray, cmap="gray")

# %%
imagem_gray.shape
# Out:
# (660, 995)

# %%
imagem = cv2.imread("imagens/px-people.jpg")
imagem = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imagem)

# %%
imagem.shape
# Out:
# (1280, 1920, 3)

# %%
imagem_roi = imagem[100:400, 1500:1850]

# %%
plt.imshow(imagem_roi)

# %%
cv2.imwrite("imagens/imagem_roi.png", imagem_roi)
# Out:
# True

# %%
imagem_roi_rgb = cv2.cvtColor(imagem_roi, cv2.COLOR_BGR2RGB)
cv2.imwrite("imagens/imagem_roi_rgb.png", imagem_roi_rgb)
# Out:
# True
